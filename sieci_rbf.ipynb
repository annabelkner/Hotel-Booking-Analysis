# %% [markdown]
# ## Wczytanie danych

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Perceptron

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/um/data_rfe_selected (1).csv')
data
# Out:
#         lead_time  arrival_date_year  arrival_date_week_number  \
# 0             342               2015                        27
# 1             737               2015                        27
# 2               7               2015                        27
# 3              13               2015                        27
# 4              14               2015                        27
# ...           ...                ...                       ...
# 119384         23               2017                        35
# 119385        102               2017                        35
# 119386         34               2017                        35
# 119387        109               2017                        35
# 119388        205               2017                        35
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  meal  \
# 0                             0                     0       2       0.0     1
# ...

# %%
X = data.drop(columns=['is_canceled'])
y = data['is_canceled']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
clf = MLPClassifier(hidden_layer_sizes=(10,),
                    activation="relu",
                    solver="adam",
                    max_iter=2000,
                    random_state=42)

clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)

print("Wyniki predykcji:", pred)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.855166802278275
# Wyniki predykcji: [0 1 1 ... 1 0 1]
# Dokładność na zbiorze testowym: 0.8529748443476561

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89     22446
#            1       0.83      0.77      0.80     13371
#
#     accuracy                           0.85     35817
#    macro avg       0.85      0.84      0.84     35817
# weighted avg       0.85      0.85      0.85     35817

# %% [markdown]
# # Perceptron

# %%
#--------------------------------------------------------
# JEDNOWARSTWOWY PERCEPTRON
#--------------------------------------------------------
clf = Perceptron(
    max_iter=1000,
    eta0=0.1,
    random_state=42)

clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.7871894893026372
# Dokładność na zbiorze testowym: 0.787726498590055

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84     22446
#            1       0.81      0.56      0.66     13371
#
#     accuracy                           0.79     35817
#    macro avg       0.79      0.74      0.75     35817
# weighted avg       0.79      0.79      0.78     35817

# %%
clf= Perceptron(
    penalty='l2',
    alpha=0.0001,
    eta0=0.01,
    max_iter=1000,
    random_state=42
)
clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.7639520413535634
# Dokładność na zbiorze testowym: 0.7607002261495938

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.99      0.84     22446
#            1       0.95      0.38      0.54     13371
#
#     accuracy                           0.76     35817
#    macro avg       0.84      0.68      0.69     35817
# weighted avg       0.81      0.76      0.73     35817

# %%
clf= Perceptron(
    class_weight='balanced',
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    eta0=0.1,
    max_iter=1000,
    random_state=42
)
clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.7644306705595175
# Dokładność na zbiorze testowym: 0.7605047882290532

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.98      0.84     22446
#            1       0.93      0.39      0.55     13371
#
#     accuracy                           0.76     35817
#    macro avg       0.83      0.68      0.69     35817
# weighted avg       0.80      0.76      0.73     35817

# %%
clf= Perceptron(
    class_weight='balanced',
    early_stopping=True,
    validation_fraction=0.1,
    n_iter_no_change=5,
    eta0=0.1,
    max_iter=1000,
    random_state=42
)
clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.7644306705595175
# Dokładność na zbiorze testowym: 0.7605047882290532

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.98      0.84     22446
#            1       0.93      0.39      0.55     13371
#
#     accuracy                           0.76     35817
#    macro avg       0.83      0.68      0.69     35817
# weighted avg       0.80      0.76      0.73     35817

# %%
clf = Perceptron(
    penalty = 'elasticnet',
    alpha=0.0001,
    l1_ratio=0.75,
    shuffle = False,
    random_state=42,
    early_stopping = True,
    validation_fraction=0.5,
    n_iter_no_change=4,
    class_weight = 'balanced'
)
clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.7546905662183506
# Dokładność na zbiorze testowym: 0.7524080743780887

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.93      0.82     22446
#            1       0.79      0.46      0.58     13371
#
#     accuracy                           0.75     35817
#    macro avg       0.76      0.69      0.70     35817
# weighted avg       0.76      0.75      0.73     35817

# %%
X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(X, y, test_size=0.30, stratify=y, random_state=42)
pipeline_clf = Pipeline([
    ('scaler', MinMaxScaler()),
    ('clf', Perceptron(random_state=42, penalty='elasticnet'))
])

param_grid_clf = {
    'clf__alpha': [0.0001, 0.001],
    'clf__l1_ratio': [0.25,0.5, 0.75],
    'clf__class_weight': ['balanced', None],
    'clf__early_stopping': [True, False],
    'clf__shuffle': [True, False]
}

grid_clf = GridSearchCV(pipeline_clf, param_grid_clf, cv=5, scoring='f1', n_jobs=-1)
grid_clf.fit(X_train_raw, y_train_raw)

print("Najlepsze parametry dla jednego perceptrou:", grid_clf.best_params_)
# Out:
# Najlepsze parametry dla jednego perceptrou: {'clf__alpha': 0.0001, 'clf__class_weight': 'balanced', 'clf__early_stopping': True, 'clf__l1_ratio': 0.75, 'clf__shuffle': False}

# %%
clf = Perceptron(
    random_state=42,
    penalty = 'elasticnet',
    alpha=0.0001,
    class_weight = 'balanced',
    l1_ratio=0.75,
    shuffle = False,
    early_stopping = True,
)
clf.fit(X_train,y_train)

train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.5694132005935002
# Dokładność na zbiorze testowym: 0.5778261719295307

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.34      0.50     22446
#            1       0.47      0.98      0.63     13371
#
#     accuracy                           0.58     35817
#    macro avg       0.72      0.66      0.57     35817
# weighted avg       0.78      0.58      0.55     35817

# %% [markdown]
# # Funkcja sigmoidalna

# %%
#--------------------------------------------------------
# jeden neuron z funkcją sigmoidalną
#--------------------------------------------------------

clf = LogisticRegression(
    max_iter=2000,
    solver='lbfgs'
)

clf.fit(X_train,y_train)
train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Wyniki predykcji:", pred)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8071842243813717
# Wyniki predykcji: [0 1 0 ... 1 0 1]
# Dokładność na zbiorze testowym: 0.80606974341793

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.85     22446
#            1       0.81      0.63      0.71     13371
#
#     accuracy                           0.81     35817
#    macro avg       0.81      0.77      0.78     35817
# weighted avg       0.81      0.81      0.80     35817

# %%
clf = LogisticRegression(
    penalty='l1',
    solver='liblinear',
    C=0.1,
    max_iter=2000,
    random_state=42
)
clf.fit(X_train,y_train)
train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8074355047144977
# Dokładność na zbiorze testowym: 0.8059301449032582

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.85     22446
#            1       0.81      0.63      0.71     13371
#
#     accuracy                           0.81     35817
#    macro avg       0.81      0.77      0.78     35817
# weighted avg       0.81      0.81      0.80     35817

# %%
clf = LogisticRegression(
    penalty='l2',
    solver='saga',
    C=10,
    class_weight='balanced',
    max_iter=5000,
    random_state=42
)
clf.fit(X_train,y_train)
train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8054132963193414
# Dokładność na zbiorze testowym: 0.8080241226233353

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84     22446
#            1       0.73      0.78      0.75     13371
#
#     accuracy                           0.81     35817
#    macro avg       0.79      0.80      0.80     35817
# weighted avg       0.81      0.81      0.81     35817

# %% [markdown]
# # MLP

# %%
X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(X, y, test_size=0.30, stratify=y, random_state=42)
pipeline_mlp = Pipeline([
    ('scaler', MinMaxScaler()),
    ('mlp', MLPClassifier(max_iter=1000, random_state=42))
])

param_grid_mlp = {
    'mlp__hidden_layer_sizes': [(10,), (32, 16)],
    'mlp__activation': ['relu', 'tanh'],
    'mlp__alpha': [0.0001, 0.001]
}

grid_mlp = GridSearchCV(pipeline_mlp, param_grid_mlp, cv=3, scoring='f1', n_jobs=-1)
grid_mlp.fit(X_train_raw, y_train_raw)

print("Najlepsze parametry dla MLP:", grid_mlp.best_params_)
# Out:
# Najlepsze parametry dla MLP: {'mlp__activation': 'relu', 'mlp__alpha': 0.001, 'mlp__hidden_layer_sizes': (32, 16)}

# %%
clf = MLPClassifier(max_iter=1000, random_state=42, hidden_layer_sizes=(32,16),
                    activation='relu', alpha=0.001)
clf.fit(X_train,y_train)
train_accuracy = clf.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = clf.predict(X_test)
test_accuracy = clf.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.87348633513617
# Dokładność na zbiorze testowym: 0.8629142585922885

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     22446
#            1       0.84      0.79      0.81     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.86      0.85      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(max_iter=1000,
                    random_state=42,
                    hidden_layer_sizes=(64, 32, 16),
                    activation='relu',
                    alpha=0.001)
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.896472502752118
# Dokładność na zbiorze testowym: 0.8620766675042577

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     22446
#            1       0.83      0.79      0.81     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.86      0.85      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(64, 32, 16),
                    activation='relu',
                    alpha=0.05,
                    early_stopping=True,
                    n_iter_no_change=10,
                    max_iter=1000,
                    random_state=42)
mlp.fit(X_train, y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8650744268415259
# Dokładność na zbiorze testowym: 0.8576653544406287

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     22446
#            1       0.82      0.79      0.81     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.85      0.84      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32, 16),
                    activation='tanh',
                    solver='sgd',
                    learning_rate='adaptive',
                    learning_rate_init=0.01,
                    momentum=0.9,
                    max_iter=2000,
                    random_state=42)
mlp.fit(X_train, y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8732829177236395
# Dokładność na zbiorze testowym: 0.863025937404026

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89     22446
#            1       0.84      0.78      0.81     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.86      0.85      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(128,),
                    activation='tanh',
                    solver='adam',
                    alpha=0.001,
                    max_iter=1000,
                    random_state=42)
mlp.fit(X_train, y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8827717417316805
# Dokładność na zbiorze testowym: 0.8653432727475779

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     22446
#            1       0.84      0.79      0.81     13371
#
#     accuracy                           0.87     35817
#    macro avg       0.86      0.85      0.85     35817
# weighted avg       0.86      0.87      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32, 16, 8),max_iter=2000, early_stopping=True,
                    random_state=42, alpha=0.0001, activation='relu')
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8545445843105346
# Dokładność na zbiorze testowym: 0.8511600636569226

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88     22446
#            1       0.83      0.75      0.79     13371
#
#     accuracy                           0.85     35817
#    macro avg       0.85      0.83      0.84     35817
# weighted avg       0.85      0.85      0.85     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32, 16, 8),max_iter=2000, early_stopping=True,
                    random_state=42, alpha=0.001, activation='relu')
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8681137222993347
# Dokładność na zbiorze testowym: 0.8619091492866516

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.91      0.89     22446
#            1       0.84      0.78      0.81     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.86      0.85      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32, 16, 8),max_iter=2000, early_stopping=True,
                    random_state=42, alpha=0.01, activation='relu')
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8609103527497248
# Dokładność na zbiorze testowym: 0.85652064662032

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89     22446
#            1       0.82      0.79      0.80     13371
#
#     accuracy                           0.86     35817
#    macro avg       0.85      0.84      0.85     35817
# weighted avg       0.86      0.86      0.86     35817

# %%
mlp = MLPClassifier(hidden_layer_sizes=(128,64), max_iter=2000, early_stopping=True,
                    random_state=42, alpha=0.0001, activation='relu',
                    validation_fraction=0.2)
mlp.fit(X_train, y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8738333413104867
# Dokładność na zbiorze testowym: 0.8619929083954547

# %%
mlp = MLPClassifier(max_iter=1000, random_state=42, hidden_layer_sizes=(64, 32, 16),
                    activation='tanh', alpha=0.0001)
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.9122074378978605
# Dokładność na zbiorze testowym: 0.8609877990898177

# %%
mlp = MLPClassifier(max_iter=1000, random_state=42, hidden_layer_sizes=(32,16),
                    activation='tanh', alpha=0.0001)
mlp.fit(X_train,y_train)
train_accuracy = mlp.score(X_train,y_train)
print("Dokładność na zbiorze uczącym:", train_accuracy)
pred = mlp.predict(X_test)
test_accuracy = mlp.score(X_test, y_test)
print("Dokładność na zbiorze testowym:", test_accuracy)
# Out:
# Dokładność na zbiorze uczącym: 0.8802828698607189
# Dokładność na zbiorze testowym: 0.8676885277940642

# %%
mlp = MLPClassifier(hidden_layer_sizes=(32, 16),max_iter=2000,
                    random_state=42, alpha=0.0001, activation='tanh')
scores = cross_validate(
    mlp, X_train, y_train, cv=5, return_train_score=True,
    scoring=("accuracy", "precision", "recall", "f1")
)
scores
# Out:
# {'fit_time': array([162.67143559, 141.97471666, 197.6990757 , 172.42086744,
#         200.14787459]),
#  'score_time': array([0.0725565 , 0.07198262, 0.07184386, 0.07191157, 0.08117318]),
#  'test_accuracy': array([0.86084355, 0.86204008, 0.86059591, 0.86490367, 0.8643652 ]),
#  'train_accuracy': array([0.8797882 , 0.87718564, 0.87983487, 0.88029854, 0.88040324]),
#  'test_precision': array([0.85152679, 0.83602852, 0.84719711, 0.82224053, 0.82552127]),
#  'train_precision': array([0.87683391, 0.86210536, 0.8782261 , 0.84553553, 0.8478279 ]),
#  'test_recall': array([0.75465889, 0.77912818, 0.75931929, 0.8089141 , 0.80210697]),
#  'train_recall': array([0.78457113, 0.79437624, 0.78308079, 0.82679686, 0.82392027]),
#  'test_f1': array([0.80017182, 0.80657608, 0.8008547 , 0.81552288, 0.8136457 ]),
#  'train_f1': array([0.8281407 , 0.82685617, 0.82792889, 0.83606121, 0.83570313])}
