# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from yellowbrick.classifier import PrecisionRecallCurve
from yellowbrick.classifier import ROCAUC
from sklearn.svm import SVC

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/um/train_pca40.csv')
data
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0      0.782619 -0.165917 -0.219862  0.712675 -0.064214 -0.378770  0.166762
# 1     -1.120342  0.908615 -0.117027 -0.146905 -0.698559 -0.292186 -0.134491
# 2      0.875860  0.003567  0.075119 -0.269167 -0.073939  0.167416 -0.114651
# 3      0.365522 -0.369521  0.459325  0.570857 -0.551908  0.653146 -0.616614
# 4      0.669381 -0.094590 -0.142664  0.708014 -0.155034 -0.236044  0.274811
# ...         ...       ...       ...       ...       ...       ...       ...
# 83567  0.764356  0.158492 -0.062301  0.117004  0.037331 -0.573156  0.130312
# 83568  1.032287  0.004518 -0.100474 -0.461922 -0.065322  0.100233  0.091894
# 83569  0.816929  0.153655  0.038722 -0.138058  0.098029 -0.658162 -0.034018
# 83570  0.275439 -0.158320  0.390454  0.963911 -0.442348 -0.447976 -0.348420
# 83571 -1.605901 -0.988015 -0.936715  0.213041 -0.345816 -0.391107 -0.545466
#
# ...

# %%
X_train = data.drop('is_canceled', axis=1)
y_train = data['is_canceled']

# %%
data_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/um/test_pca40.csv')

# %%
X_test = data_test.drop('is_canceled', axis=1)
y_test = data_test['is_canceled']

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression(solver='saga', C=100, penalty='l1', max_iter = 1000)
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
print(accuracy_score(y_test,y_pred))

# %%
print(classification_report(y_test, y_pred))

# %%
confusion_matrix(y_test, y_pred)

# %%
param_grid_lr = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]
}
grid_lr = GridSearchCV(LogisticRegression(solver='saga', max_iter=1000), param_grid_lr, cv=5, scoring = 'f1', n_jobs=-1)
grid_lr.fit(X_train, y_train)
print("Najlepsze parametry:", grid_lr.best_params_)
# Out:
# Najlepsze parametry: {'C': 10, 'penalty': 'l1'}

# %%
lr = LogisticRegression(solver = 'saga', max_iter = 1000, C = 10, penalty = 'l1')
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=10, max_iter=1000, penalty='l1', solver='saga')

# %%
y_pred = lr.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7852974844347657

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84     22446
#            1       0.79      0.58      0.67     13371
#
#     accuracy                           0.79     35817
#    macro avg       0.79      0.74      0.75     35817
# weighted avg       0.79      0.79      0.78     35817

# %% [markdown]
# ## k-NN

# %%
param_grid_knn = {
    'n_neighbors': [5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

grid_knn = GridSearchCV(KNeighborsClassifier(), param_grid_knn, cv=5, scoring='f1', n_jobs=-1)
grid_knn.fit(X_train, y_train)

print("Najlepsze parametry KNN:", grid_knn.best_params_)
# Out:
# Najlepsze parametry KNN: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}

# %%
klasyfikator = KNeighborsClassifier(n_neighbors=9,weights='distance', metric = 'manhattan')
klasyfikator.fit(X_train,y_train)
y_pred= klasyfikator.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8451294078231008

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[19977,  2469],
#        [ 3078, 10293]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88     22446
#            1       0.81      0.77      0.79     13371
#
#     accuracy                           0.85     35817
#    macro avg       0.84      0.83      0.83     35817
# weighted avg       0.84      0.85      0.84     35817

# %% [markdown]
# ## SVM

# %%
X_sample, _, y_sample, _ = train_test_split(X_train, y_train, train_size=20000, stratify=y_train, random_state=42)


param_grid_svc = [
    {'kernel': ['rbf'], 'C': [0.1, 1, 10]},
    {'kernel': ['poly'], 'C': [0.1, 1, 10], 'degree': [2, 3]}
]

grid_svc = GridSearchCV(SVC(), param_grid_svc, cv=3, n_jobs=-1)
grid_svc.fit(X_sample, y_sample)

print("Najlepsze parametry SVC:", grid_svc.best_params_)
# Out:
# Najlepsze parametry SVC: {'C': 10, 'kernel': 'rbf'}

# %%
from sklearn.svm import SVC
svm = SVC(kernel="rbf", C=10)
svm.fit(X_train, y_train)
# Out:
# SVC(C=10)

# %%
y_pred_svm = svm.predict(X_test)
accuracy_score(y_test, y_pred_svm)
# Out:
# 0.8417790434709774

# %%
confusion_matrix(y_test, y_pred_svm)
# Out:
# array([[20402,  2044],
#        [ 3623,  9748]])

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88     22446
#            1       0.83      0.73      0.77     13371
#
#     accuracy                           0.84     35817
#    macro avg       0.84      0.82      0.83     35817
# weighted avg       0.84      0.84      0.84     35817

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE(sampling_strategy='minority', random_state=42)
X_train_sm, y_train_sm = smote.fit_resample(X_train, y_train)

# %%
model = KNeighborsClassifier(n_neighbors=9,weights='distance', metric = 'manhattan')
model.fit(X_train_sm, y_train_sm)
y_pred_sm = model.predict(X_test)
print(accuracy_score(y_test, y_pred_sm))
# Out:
# 0.8267024038864227

# %%
print(classification_report(y_test, y_pred_sm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86     22446
#            1       0.74      0.82      0.78     13371
#
#     accuracy                           0.83     35817
#    macro avg       0.81      0.83      0.82     35817
# weighted avg       0.83      0.83      0.83     35817

# %%
cm = confusion_matrix(y_test, y_pred_sm)
cm
# Out:
# array([[18655,  3791],
#        [ 2416, 10955]])

# %%
svm = SVC(kernel="poly", degree=3, C=10)
svm.fit(X_train_sm, y_train_sm)
y_pred_svm = svm.predict(X_test)
accuracy_score(y_test, y_pred_svm)
# Out:
# 0.8272328782421755

# %%
confusion_matrix(y_test, y_pred_svm)
# Out:
# array([[18680,  3766],
#        [ 2422, 10949]])

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86     22446
#            1       0.74      0.82      0.78     13371
#
#     accuracy                           0.83     35817
#    macro avg       0.81      0.83      0.82     35817
# weighted avg       0.83      0.83      0.83     35817
